# %%
# import appropriate packages
import os
import requests
import json 
import pandas as pd
from datetime import datetime
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore") #supress warnings

# %%
import requests
from tqdm.notebook import tqdm

def fetch_total_pages(api_url, dataset_type_id, dataset_version_id, page_size=1000):
    current_page = 1
    
    try:
        with tqdm(desc="Fetching Total Records", unit="page") as pbar:
            while True:
                params = {
                    'page': current_page,
                    'size': page_size,
                    'dataset_type_id': dataset_type_id,
                    'dataset_version_id': dataset_version_id
                }
                response = requests.get(api_url, params=params)
                response.raise_for_status()
                
                data = response.json()
                
                if not data:
                    break
                
                # Update progress bar
                pbar.update(1)
                
                if len(data) < page_size:
                    break
                
                current_page += 1
                
        # Calculate total pages
        total_pages = current_page
        return total_pages
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {str(e)}")
        return None

# Example usage
if __name__ == "__main__":
    api_url = 'https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data'
    dataset_type_id = '8900b9c5-50b7-43de-9bdd-0d7113a8355e'
    dataset_version_id = 'c9537569-13f5-42d1-8c0a-dd7264629d6a'
    
    # Fetch total pages
    total_pages = fetch_total_pages(api_url, dataset_type_id, dataset_version_id)
    if total_pages is not None:
        print(f"Total pages available: {total_pages}")
# Out:
# Fetching Total Records: 0page [00:00, ?page/s]

# %%
import requests
import pandas as pd
from tqdm.notebook import tqdm

def fetch_all_pages(api_url, dataset_type_id, dataset_version_id, page_size=1000, total_rows=1044711):
    all_data = []
    offset = 0  # Offset instead of page number
    total_pages = (total_rows // page_size) + 1  # Calculate the total number of pages

    try:
        with tqdm(total=total_pages, desc="Fetching Data") as pbar:
            while offset < total_rows:
                params = {
                    'start': offset,  # Use 'start' instead of 'page'
                    'size': page_size,
                    'dataset_type_id': dataset_type_id,
                    'dataset_version_id': dataset_version_id
                }
                print(f"Requesting URL: {api_url} with params: {params}")  # Debug statement
                response = requests.get(api_url, params=params)
                response.raise_for_status()
                
                data = response.json()
                
                print(f"Fetched {len(data)} records from offset {offset}")  # Debug statement
                if offset == 0:
                    print(f"First few records from offset {offset}: {data[:3]}")  # Print first few records of the first page for inspection
                if offset == page_size:
                    print(f"First few records from offset {offset}: {data[:3]}")  # Print first few records of the second page for comparison
                
                all_data.extend(data)
                
                # Update progress bar
                pbar.update(1)
                
                # Check if there are more pages based on returned data size
                if len(data) < page_size:
                    break
                
                # Increment offset for next request
                offset += page_size
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {str(e)}")
    
    return all_data

# Example usage
if __name__ == "__main__":
    api_url = 'https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data'
    dataset_type_id = '8900b9c5-50b7-43de-9bdd-0d7113a8355e'
    dataset_version_id = 'c9537569-13f5-42d1-8c0a-dd7264629d6a'
    
    # Fetch all pages of data
    all_data = fetch_all_pages(api_url, dataset_type_id, dataset_version_id)
    
    # Convert all data to DataFrame
    df = pd.DataFrame(all_data)
    print(f"Total rows fetched: {len(df)}")
    print(df.head())  # Displaying the first few rows as an example
# Out:
# Fetching Data:   0%|          | 0/1045 [00:00<?, ?it/s]
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 0, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 0
# First few records from offset 0: [{'reference_period': '2019-01-01 to 2019-12-31', 'type_of_service': 'Ambulance (Emergency & Non-Emergency)', 'aggregation_level': 'NATION + TERRITORIES', 'state': '--ALL--', 'county': '--ALL--', 'state_fips': ' ', 'county_fips': ' ', 'number_of_fee_for_service_beneficiaries': '36,122,263', 'number_of_providers': '8,814', 'average_number_of_users_per_provider': '495.69', 'percentage_of_users_out_of_ffs_beneficiaries': '12.09%', 'number_of_users': '4,368,976', 'average_number_of_providers_per_county': '39.85', 'number_of_dual_eligible_users': '1,348,463', 'percentage_of_dual_eligible_users_out_of_total_users': '30.86%', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': '20.52%', 'total_payment': '$4,037,494,106.32', 'moratorium': ' ', 'number_of_fee_for_service_beneficiaries_dual_color': ' ', 'number_of_fee_for_service_beneficiaries_description': ' ', 'number_of_providers_dual_color': ' ', 'number_of_providers_description': ' ', 'average_number_of_users_per_provider_dual_color': ' ', 'average_number_of_users_per_provider_description': ' ', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color': ' ', 'percentage_of_users_out_of_ffs_beneficiaries_description': ' ', 'number_of_users_dual_color': ' ', 'number_of_users_description': ' ', 'average_number_of_providers_per_county_dual_color': ' ', 'average_number_of_providers_per_county_description': ' ', 'number_of_dual_eligible_users_dual_color': ' ', 'number_of_dual_eligible_users_description': ' ', 'percentage_of_dual_eligible_users_out_of_total_users_dual_color': ' ', 'percentage_of_dual_eligible_users_out_of_total_users_description': ' ', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color': ' ', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description': ' ', 'total_payment_dual_color': ' ', 'total_payment_description': ' ', 'number_of_fee_for_service_beneficiaries_change': '5.81%', 'number_of_providers_change': '0.34%', 'average_number_of_users_per_provider_change': '1.28%', 'percentage_of_users_out_of_ffs_beneficiaries_change': '( 3.97%)', 'number_of_users_change': '1.62%', 'average_number_of_providers_per_county_change': '1.19%', 'number_of_dual_eligible_users_change': '( 4.89%)', 'percentage_of_dual_eligible_users_out_of_total_users_change': '( 6.43%)', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change': '( 1.20%)', 'total_payment_change': '1.80%'}, {'reference_period': '2019-01-01 to 2019-12-31', 'type_of_service': 'Ambulance (Emergency & Non-Emergency)', 'aggregation_level': 'STATE', 'state': 'AL', 'county': '--ALL--', 'state_fips': '01', 'county_fips': ' ', 'number_of_fee_for_service_beneficiaries': '547,486', 'number_of_providers': '146', 'average_number_of_users_per_provider': '501.47', 'percentage_of_users_out_of_ffs_beneficiaries': '13.37%', 'number_of_users': '73,215', 'average_number_of_providers_per_county': '12.3', 'number_of_dual_eligible_users': '24,610', 'percentage_of_dual_eligible_users_out_of_total_users': '33.61%', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': '21.14%', 'total_payment': '$74,641,552.63', 'moratorium': 'No', 'number_of_fee_for_service_beneficiaries_dual_color': 'BLUE 3', 'number_of_fee_for_service_beneficiaries_description': 'Third Lowest 25% (460,144 - 821,312 Beneficiaries)', 'number_of_providers_dual_color': 'BLUE 2', 'number_of_providers_description': 'Second Lowest 25% (71 - 146 Providers)', 'average_number_of_users_per_provider_dual_color': 'BLUE 4', 'average_number_of_users_per_provider_description': 'Top 25% Excl. Extreme Values (495.13 - 898.40 Users)', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color': 'BLUE 4', 'percentage_of_users_out_of_ffs_beneficiaries_description': 'Top 25% Excl. Extreme Values (13.02% - 15.97% of Users)', 'number_of_users_dual_color': 'BLUE 3', 'number_of_users_description': 'Third Lowest 25% (50,565 - 100,311 Users)',  ...
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 1000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 1000
# First few records from offset 1000: [{'reference_period': '2019-01-01 to 2019-12-31', 'type_of_service': 'Ambulance (Emergency & Non-Emergency)', 'aggregation_level': 'NATION + TERRITORIES', 'state': '--ALL--', 'county': '--ALL--', 'state_fips': ' ', 'county_fips': ' ', 'number_of_fee_for_service_beneficiaries': '36,122,263', 'number_of_providers': '8,814', 'average_number_of_users_per_provider': '495.69', 'percentage_of_users_out_of_ffs_beneficiaries': '12.09%', 'number_of_users': '4,368,976', 'average_number_of_providers_per_county': '39.85', 'number_of_dual_eligible_users': '1,348,463', 'percentage_of_dual_eligible_users_out_of_total_users': '30.86%', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': '20.52%', 'total_payment': '$4,037,494,106.32', 'moratorium': ' ', 'number_of_fee_for_service_beneficiaries_dual_color': ' ', 'number_of_fee_for_service_beneficiaries_description': ' ', 'number_of_providers_dual_color': ' ', 'number_of_providers_description': ' ', 'average_number_of_users_per_provider_dual_color': ' ', 'average_number_of_users_per_provider_description': ' ', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color': ' ', 'percentage_of_users_out_of_ffs_beneficiaries_description': ' ', 'number_of_users_dual_color': ' ', 'number_of_users_description': ' ', 'average_number_of_providers_per_county_dual_color': ' ', 'average_number_of_providers_per_county_description': ' ', 'number_of_dual_eligible_users_dual_color': ' ', 'number_of_dual_eligible_users_description': ' ', 'percentage_of_dual_eligible_users_out_of_total_users_dual_color': ' ', 'percentage_of_dual_eligible_users_out_of_total_users_description': ' ', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color': ' ', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description': ' ', 'total_payment_dual_color': ' ', 'total_payment_description': ' ', 'number_of_fee_for_service_beneficiaries_change': '5.81%', 'number_of_providers_change': '0.34%', 'average_number_of_users_per_provider_change': '1.28%', 'percentage_of_users_out_of_ffs_beneficiaries_change': '( 3.97%)', 'number_of_users_change': '1.62%', 'average_number_of_providers_per_county_change': '1.19%', 'number_of_dual_eligible_users_change': '( 4.89%)', 'percentage_of_dual_eligible_users_out_of_total_users_change': '( 6.43%)', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change': '( 1.20%)', 'total_payment_change': '1.80%'}, {'reference_period': '2019-01-01 to 2019-12-31', 'type_of_service': 'Ambulance (Emergency & Non-Emergency)', 'aggregation_level': 'STATE', 'state': 'AL', 'county': '--ALL--', 'state_fips': '01', 'county_fips': ' ', 'number_of_fee_for_service_beneficiaries': '547,486', 'number_of_providers': '146', 'average_number_of_users_per_provider': '501.47', 'percentage_of_users_out_of_ffs_beneficiaries': '13.37%', 'number_of_users': '73,215', 'average_number_of_providers_per_county': '12.3', 'number_of_dual_eligible_users': '24,610', 'percentage_of_dual_eligible_users_out_of_total_users': '33.61%', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': '21.14%', 'total_payment': '$74,641,552.63', 'moratorium': 'No', 'number_of_fee_for_service_beneficiaries_dual_color': 'BLUE 3', 'number_of_fee_for_service_beneficiaries_description': 'Third Lowest 25% (460,144 - 821,312 Beneficiaries)', 'number_of_providers_dual_color': 'BLUE 2', 'number_of_providers_description': 'Second Lowest 25% (71 - 146 Providers)', 'average_number_of_users_per_provider_dual_color': 'BLUE 4', 'average_number_of_users_per_provider_description': 'Top 25% Excl. Extreme Values (495.13 - 898.40 Users)', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color': 'BLUE 4', 'percentage_of_users_out_of_ffs_beneficiaries_description': 'Top 25% Excl. Extreme Values (13.02% - 15.97% of Users)', 'number_of_users_dual_color': 'BLUE 3', 'number_of_users_description': 'Third Lowest 25% (50,565 - 100,311 Users) ...
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 2000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 2000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 3000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 3000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 4000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 4000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 5000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 5000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 6000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 6000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 7000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 7000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 8000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 8000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 9000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 9000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 10000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 10000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 11000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 11000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 12000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 12000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 13000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 13000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 14000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 14000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 15000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 15000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 16000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 16000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 17000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 17000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 18000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 18000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 19000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 19000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 20000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 20000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 21000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 21000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 22000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 22000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 23000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 23000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 24000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 24000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 25000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 25000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 26000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 26000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 27000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 27000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 28000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 28000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 29000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 29000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 30000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 30000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 31000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 31000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 32000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 32000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 33000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 33000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 34000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 34000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 35000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 35000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 36000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 36000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 37000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 37000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 38000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 38000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 39000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 39000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 40000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 40000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 41000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 41000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 42000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 42000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 43000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 43000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 44000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 44000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 45000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 45000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 46000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 46000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 47000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 47000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 48000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 48000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 49000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 49000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 50000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 50000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 51000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 51000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 52000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 52000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 53000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 53000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 54000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 54000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 55000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 55000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 56000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 56000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 57000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 57000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 58000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 58000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 59000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 59000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 60000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 60000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 61000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 61000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 62000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 62000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 63000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 63000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 64000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 64000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 65000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 65000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 66000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 66000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 67000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 67000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 68000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 68000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 69000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 69000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 70000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 70000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 71000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 71000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 72000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 72000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 73000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 73000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 74000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 74000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 75000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# Fetched 1000 records from offset 75000
# Requesting URL: https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data with params: {'start': 76000, 'size': 1000, 'dataset_type_id': '8900b9c5-50b7-43de-9bdd-0d7113a8355e', 'dataset_version_id': 'c9537569-13f5-42d1-8c0a-dd7264629d6a'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7x/mfyhhlkn0fz774bmn50_szsm0000gn/T/ipykernel_89980/3204603927.py in <module>
#      53
#      54     # Fetch all pages of data
# ---> 55     all_data = fetch_all_pages(api_url, dataset_type_id, dataset_version_id)
#      56
#      57     # Convert all data to DataFrame
#
# /var/folders/7x/mfyhhlkn0fz774bmn50_szsm0000gn/T/ipykernel_89980/3204603927.py in fetch_all_pages(api_url, dataset_type_id, dataset_version_id, page_size, total_rows)
#      18                 }
#      19                 print(f"Requesting URL: {api_url} with params: {params}")  # Debug statement
# ---> 20                 response = requests.get(api_url, params=params)
#      21                 response.raise_for_status()
#      22
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     625         else:
#     626             while not is_fp_closed(self._fp):
# --> 627                 data = self.read(amt=amt, decode_content=decode_content)
#     628
#     629                 if data:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     564
#     565         with self._error_catcher():
# --> 566             data = self._fp_read(amt) if not fp_closed else b""
#     567             if amt is None:
#     568                 flush_decoder = True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/response.py in _fp_read(self, amt)
#     530         else:
#     531             # StringIO doesn't like amt=None
# --> 532             return self._fp.read(amt) if amt is not None else self._fp.read()
#     533
#     534     def read(self, amt=None, decode_content=None, cache_content=False):
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in read(self, amt)
#     461             # Amount is given, implement using readinto
#     462             b = bytearray(amt)
# --> 463             n = self.readinto(b)
#     464             return memoryview(b)[:n].tobytes()
#     465         else:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in readinto(self, b)
#     505         # connection, and the user is reading more bytes than will be provided
#     506         # (for example, reading in 1k chunks)
# --> 507         n = self.fp.readinto(b)
#     508         if not n and b:
#     509             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [raw]
# import requests
# from bs4 import BeautifulSoup
# from urllib.parse import urljoin
# from tqdm.notebook import tqdm  # Import tqdm for progress bar in Jupyter Notebook
#
# def fetch_all_pages(api_url):
#     all_data = []
#     url = api_url
#
#     try:
#         while url:
#             response = requests.get(url)
#             response.raise_for_status()
#
#             soup = BeautifulSoup(response.text, 'html.parser')
#
#             # Debugging: Print out the page structure to find correct selectors
#             print(soup.prettify())
#
#             # Example: Fetching footer element
#             footer_element = soup.select_one('li.current')
#             if footer_element:
#                 print(footer_element.text.strip())  # Print or process footer element
#
#             # Pagination: Find next page URL
#             next_page_element = soup.select_one('li.next > a')
#             if next_page_element:
#                 next_page_url = next_page_element.get('href')
#                 url = urljoin(url, next_page_url)
#             else:
#                 url = None  # Break loop if no more next page
#
#             # Update progress bar
#             tqdm.write(f"Fetched page {len(all_data) // 1000 + 1}")  # Assuming 1000 rows per page
#
#     except requests.exceptions.RequestException as e:
#         print(f"Error fetching data: {str(e)}")
#
#     return all_data
#
# # Example usage
# if __name__ == "__main__":
#     api_url = 'https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data'
#
#     # Fetch all pages of data
#     fetch_all_pages(api_url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045000 entries, 0 to 1044999
# Data columns (total 48 columns):
#  #   Column                                                                                Non-Null Count    Dtype
# ---  ------                                                                                --------------    -----
#  0   reference_period                                                                      1045000 non-null  object
#  1   type_of_service                                                                       1045000 non-null  object
#  2   aggregation_level                                                                     1045000 non-null  object
#  3   state                                                                                 1045000 non-null  object
#  4   county                                                                                1045000 non-null  object
#  5   state_fips                                                                            1045000 non-null  object
#  6   county_fips                                                                           1045000 non-null  object
#  7   number_of_fee_for_service_beneficiaries                                               1045000 non-null  object
#  8   number_of_providers                                                                   1045000 non-null  object
#  9   average_number_of_users_per_provider                                                  1045000 non-null  object
#  10  percentage_of_users_out_of_ffs_beneficiaries                                          1045000 non-null  object
#  11  number_of_users                                                                       1045000 non-null  object
#  12  average_number_of_providers_per_county                                                1045000 non-null  object
#  13  number_of_dual_eligible_users                                                         1045000 non-null  object
#  14  percentage_of_dual_eligible_users_out_of_total_users                                  1045000 non-null  object
#  15  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries              1045000 non-null  object
#  16  total_payment                                                                         1045000 non-null  object
#  17  moratorium                                                                            1045000 non-null  object
#  18  number_of_fee_for_service_beneficiaries_dual_color                                    1045000 non-null  object
#  19  number_of_fee_for_service_beneficiaries_description                                   1045000 non-null  object
#  20  number_of_providers_dual_color                                                        1045000 non-null  object
#  21  number_of_providers_description                                                       1045000 non-null  object
#  22  average_number_of_users_per_provider_dual_color                                       1045000 non-null  object
#  23  average_number_of_users_per_provider_description                                      1045000 non-null  object
#  24  percentage_of_users_out_of_ffs_beneficiaries_dual_color                               1045000 non-null  object
#  25  percentage_of_users_out_of_ffs_beneficiaries_description                              1045000 non-null  object
#  26  number_of_users_dual_color                                                            1045000 non-null  object
#  27  number_of_users_description                                                           1045000 non-null  object
#  28  average_number_of_providers_per_county_dual_color                                     1045000 non-null  object
#  29  average_number_of_providers_per_county_description                                    1045000 non-null  object
#  30  number_of_dual_eligible_users_dual_color                                              1045000 non-null  object
#  31  number_of_dual_eligible_users_description                                             1045000 non-null  object
#  32  percentage_of_dual_eligible_users_out_of_total_users_dual_color                       1045000 non-null  object
#  33  percentage_of_dual_eligible_users_out_of_total_users_description                      1045000 non-null  object
#  34  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color   1045000 non-null  object
#  35  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description  1045000 non-null  object
#  36  total_payment_dual_color                                                              1045000 non-null  object
#  37  total_payment_description                                                             1045000 non-null  object
#  38  number_of_fee_for_service_beneficiaries_change                                        1045000 non-null  object
#  39  number_of_providers_change                                                            1045000 non-null  object
#  40  average_number_of_users_per_provider_change                                           1045000 non-null  object
#  41  percentage_of_users_out_of_ffs_beneficiaries_change                                   1045000 non-null  object
#  42  number_of_users_change                                                                1045000 non-null  object
#  43  average_number_of_providers_per_county_change                                         1045000 non-null  object
#  44  number_of_dual_eligible_users_change                                                  1045000 non-null  object
#  45  percentage_of_dual_eligible_users_out_of_total_users_change                           1045000 non-null  object
#  46  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change       1045000 non-null  object
#  47  total_payment_change                                                                  1045000 non-null  object
# dtypes: object(48)
# memory usage: 382.7+ MB

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1044995     True
# 1044996     True
# 1044997     True
# 1044998     True
# 1044999     True
# Length: 1045000, dtype: bool
