# %% [markdown]
# # Uncovering Healthcare Inefficiencies - Data Retrival via API
#
# This notebook is dedicated to retrieving data from the Centers for Medicare & Medicaid Services (CMS) via their API. The specific dataset of interest is the [Market Saturation and Utilization Data](https://data.cms.gov/summary-statistics-on-use-and-payments/program-integrity-market-saturation-by-type-of-service/market-saturation-utilization-state-county).
#
# The primary objective is comprehensive data retrieval, ensuring a broad scope of Medicare Fee-for-Service (FFS) claims from the CMS Integrated Data Repository (IDR). This dataset is updated quarterly and covers a 12-month reference period, providing critical insights into market saturation and utilization at the state and county levels.
#
# ---
#
# ## Table of Contents
# 1. [Import Libaries](#import-libaries)
# 2. [Define API Endpoint and Import Data](#define-api-enpoint-and-import-data)
# 3. [Data Storage](#data-storage)
# 4. [SQL Database Preperation](#sql-database-preperation)
#
# ## Import Libaries
#
# The following libraries are imported to support the data retrival process:

# %%
# import necessary libaries 
import os
import requests
import json 
import pandas as pd
from datetime import datetime
from tqdm import tqdm
import time
import random
import openpyxl
from requests.exceptions import SSLError

import warnings
warnings.filterwarnings("ignore") #supress warnings

# %% [markdown]
# ## Define API Enpoint and Import Data
#
# The API endpoint provided by CMS returns JSON data, which is directly parsed into a Python dictionary for further processing. The successful response check ensures data integrity, while error handling is implemented to address any issues with the API request. This method provides a foundational step for collecting the necessary data to support subsequent analysis.

# %%
# define base URL for the API
base_url = "https://data.cms.gov/data-api/v1/dataset/8900b9c5-50b7-43de-9bdd-0d7113a8355e/data"

# send the GET request to the API
response = requests.get(base_url)

# check if request was successful
if response.status_code == 200:
    # parse the JSON data from the response
    data = response.json()
    # minimize output by showing only a brief summary or a sample
    sample_data = data[:5] 
    print("Sample Data:")
    # print sample response 
    print(sample_data)
    # Example: Display key information about the response
    print("\nData Summary:")
    print(f"Total records: {len(data)}")
    print(f"Keys in first record: {list(data[0].keys()) if data else 'No data'}")
else:
    # handle the error
    print(f"Error: {response.status_code}")
# Out:
# Sample Data:
# [{'reference_period': '2020-01-01 to 2020-12-31', 'type_of_service': 'Ambulance (Emergency & Non-Emergency)', 'aggregation_level': 'NATION + TERRITORIES', 'state': '--ALL--', 'county': '--ALL--', 'state_fips': ' ', 'county_fips': ' ', 'number_of_fee_for_service_beneficiaries': '36,342,691', 'number_of_providers': '8,780', 'average_number_of_users_per_provider': '457.58', 'percentage_of_users_out_of_ffs_beneficiaries': '11.05%', 'number_of_users': '4,017,592', 'average_number_of_providers_per_county': '35.81', 'number_of_dual_eligible_users': '1,151,473', 'percentage_of_dual_eligible_users_out_of_total_users': '28.66%', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': '19.35%', 'total_payment': '$3,731,546,031.63', 'moratorium': ' ', 'number_of_fee_for_service_beneficiaries_dual_color': ' ', 'number_of_fee_for_service_beneficiaries_description': ' ', 'number_of_providers_dual_color': ' ', 'number_of_providers_description': ' ', 'average_number_of_users_per_provider_dual_color': ' ', 'average_number_of_users_per_provider_description': ' ', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color': ' ', 'percentage_of_users_out_of_ffs_beneficiaries_description': ' ', 'number_of_users_dual_color': ' ', 'number_of_users_description': ' ', 'average_number_of_providers_per_county_dual_color': ' ', 'average_number_of_providers_per_county_description': ' ', 'number_of_dual_eligible_users_dual_color': ' ', 'number_of_dual_eligible_users_description': ' ', 'percentage_of_dual_eligible_users_out_of_total_users_dual_color': ' ', 'percentage_of_dual_eligible_users_out_of_total_users_description': ' ', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color': ' ', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description': ' ', 'total_payment_dual_color': ' ', 'total_payment_description': ' ', 'number_of_fee_for_service_beneficiaries_change': '0.61%', 'number_of_providers_change': '( 0.39%)', 'average_number_of_users_per_provider_change': '( 7.69%)', 'percentage_of_users_out_of_ffs_beneficiaries_change': '( 8.60%)', 'number_of_users_change': '( 8.04%)', 'average_number_of_providers_per_county_change': '(10.14%)', 'number_of_dual_eligible_users_change': '(14.61%)', 'percentage_of_dual_eligible_users_out_of_total_users_change': '( 7.13%)', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change': '( 5.70%)', 'total_payment_change': '( 7.58%)'}, {'reference_period': '2020-01-01 to 2020-12-31', 'type_of_service': 'Ambulance (Emergency & Non-Emergency)', 'aggregation_level': 'STATE', 'state': 'AL', 'county': '--ALL--', 'state_fips': '01', 'county_fips': ' ', 'number_of_fee_for_service_beneficiaries': '536,961', 'number_of_providers': '145', 'average_number_of_users_per_provider': '460.60', 'percentage_of_users_out_of_ffs_beneficiaries': '12.44%', 'number_of_users': '66,787', 'average_number_of_providers_per_county': '11.56', 'number_of_dual_eligible_users': '19,736', 'percentage_of_dual_eligible_users_out_of_total_users': '29.55%', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': '19.85%', 'total_payment': '$69,283,867.06', 'moratorium': 'No', 'number_of_fee_for_service_beneficiaries_dual_color': 'BLUE 3', 'number_of_fee_for_service_beneficiaries_description': 'Third Lowest 25% (460,992 - 838,953 Beneficiaries)', 'number_of_providers_dual_color': 'BLUE 3', 'number_of_providers_description': 'Third Lowest 25% (144 - 229 Providers)', 'average_number_of_users_per_provider_dual_color': 'BLUE 3', 'average_number_of_users_per_provider_description': 'Third Lowest 25% (340.93 - 464.40 Users)', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color': 'BLUE 4', 'percentage_of_users_out_of_ffs_beneficiaries_description': 'Top 25% Excl. Extreme Values (12.01% - 14.29% of Users)', 'number_of_users_dual_color': 'BLUE 3', 'number_of_users_description': 'Third Lowest 25% (48,053 - 93,918 Users)', 'average_number_of_providers_p ...
#
# Data Summary:
# Total records: 1000
# Keys in first record: ['reference_period', 'type_of_service', 'aggregation_level', 'state', 'county', 'state_fips', 'county_fips', 'number_of_fee_for_service_beneficiaries', 'number_of_providers', 'average_number_of_users_per_provider', 'percentage_of_users_out_of_ffs_beneficiaries', 'number_of_users', 'average_number_of_providers_per_county', 'number_of_dual_eligible_users', 'percentage_of_dual_eligible_users_out_of_total_users', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries', 'total_payment', 'moratorium', 'number_of_fee_for_service_beneficiaries_dual_color', 'number_of_fee_for_service_beneficiaries_description', 'number_of_providers_dual_color', 'number_of_providers_description', 'average_number_of_users_per_provider_dual_color', 'average_number_of_users_per_provider_description', 'percentage_of_users_out_of_ffs_beneficiaries_dual_color', 'percentage_of_users_out_of_ffs_beneficiaries_description', 'number_of_users_dual_color', 'number_of_users_description', 'average_number_of_providers_per_county_dual_color', 'average_number_of_providers_per_county_description', 'number_of_dual_eligible_users_dual_color', 'number_of_dual_eligible_users_description', 'percentage_of_dual_eligible_users_out_of_total_users_dual_color', 'percentage_of_dual_eligible_users_out_of_total_users_description', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description', 'total_payment_dual_color', 'total_payment_description', 'number_of_fee_for_service_beneficiaries_change', 'number_of_providers_change', 'average_number_of_users_per_provider_change', 'percentage_of_users_out_of_ffs_beneficiaries_change', 'number_of_users_change', 'average_number_of_providers_per_county_change', 'number_of_dual_eligible_users_change', 'percentage_of_dual_eligible_users_out_of_total_users_change', 'percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change', 'total_payment_change']

# %% [markdown]
# ### Pagination
#
# Given the large size of the dataset, we implement pagination to retrieve data in manageable chunks. We define a page size and initialize an offset. A function is created to fetch data for each page with error handling for SSL errors and retries. A progress bar is used to monitor the fetching process and introduce random delays to avoid overwhelming the server.
#
# 1. Define Page Size and Initialize Offset:
# - Page Size: The number of records retrieved per page (set to 1000).
# - Offset: Tracks the starting point for each page retrieval.
# 2. Create a Function to Fetch Data for Each Page:
# - Error Handling: Includes handling for SSL errors with retry logic.
# - Retry Mechanism: Retries up to three times with a delay if an SSL error occurs.
# 3. Monitor the Fetching Process:
# - Progress Bar: Utilizes tqdm to track the progress of data retrieval.
# - Random Delays: Introduces random delays between requests to avoid overloading the server.

# %%
# set the size of each page
page_size = 1000  # number of records per page 

# initialize a list to store the data
all_data = []

# function to get data from a single page
def get_page_data(url, offset, page_size, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            response = requests.get(url, params={"offset": offset, "size": page_size})
            if response.status_code == 200:
                return response.json()
            else:
                print(f"Error: {response.status_code}")
                return None
        except SSLError as e:
            print(f"SSL Error: {e}. Retrying...")
            attempt += 1
            time.sleep(5)  # Wait before retrying
    print(f"Failed to fetch data after {retries} attempts.")
    return None

# initialize offset
offset = 0

# get the initial page of data
data = get_page_data(base_url, offset, page_size)

# fetch total records to calculate total pages
total_records = len(data)  # initialize with the length of the first page of data
total_pages = (total_records // page_size) + 1

# initialize progress bar
with tqdm(total=total_pages, desc="Fetching Data", unit="page") as pbar:
    # check if data is returned
    while data:
        all_data.extend(data)  # add data to the list
        # if number of records returned is less than the page size, we're done
        if len(data) < page_size:
            break
        # update offset for the next page
        offset += page_size
        
        # add a random delay to avoid overwhelming the server
        time.sleep(5 + 10 * random.random())
        
        # get the next page of data
        try:
            data = get_page_data(base_url, offset, page_size)
            pbar.update(1)  # Update progress bar
        except KeyboardInterrupt:
            print("Data fetching interrupted.")
            break

# create DataFrame from the collected data
df = pd.DataFrame(all_data)
# Out:
# Fetching Data: 1044page [3:44:38, 12.91s/page]
# Data saved to cms_data.xlsx

# %% [markdown]
# ## Data Storage
#
# ### Save Data to CSV file
#
# To preserve the fetched data, the data is stored both CSV and Excel formats. First, a directory named `data` if it does not already exist. Then the dataframes is saved to a CSV file.

# %%
# create directory to save data in new folder 'data'
output_dir = 'data'
os.makedirs(output_dir, exist_ok=True)

# save df to CSV file
output_file = 'data/cms_data.csv'
df.to_csv(output_file, index=False)

# %% [markdown]
# #### Data Summary
# Verify the integrity of the fetched data by examining a sample and ensuring all rows and columns are correctly imported and saved.

# %%
df.sample(20) #ensure data was imported and saved correctly
# Out:
#                 reference_period  \
# 865263  2022-07-01 to 2023-06-30
# 454     2019-01-01 to 2019-12-31
# 113238  2019-04-01 to 2020-03-31
# 679181  2021-10-01 to 2022-09-30
# 91962   2019-04-01 to 2020-03-31
# 45791   2019-01-01 to 2019-12-31
# 916971  2022-07-01 to 2023-06-30
# 895189  2022-07-01 to 2023-06-30
# 971433  2022-10-01 to 2023-09-30
# 127111  2019-07-01 to 2020-06-30
# 956606  2022-10-01 to 2023-09-30
# 564430  2021-04-01 to 2022-03-31
# 701373  2021-10-01 to 2022-09-30
# 306565  2020-01-01 to 2020-12-31
# 508103  2021-01-01 to 2021-12-31
# 753166  2022-01-01 to 2022-12-31
# 133076  2019-07-01 to 2020-06-30
# 686613  2021-10-01 to 2022-09-30
# 929428  2022-10-01 to 2023-09-30
# 999831  2023-01-01 to 2023-12-31
#
#                                      type_of_service aggregation_level state  \
# 865263                         Ambulance (Emergency)            COUNTY    IA
# 454            Ambulance (Emergency & Non-Emergency)            COUNTY    GA
# 113238                                 Psychotherapy            COUNTY    TX
# 679181         Ambulance (Emergency & Non-Emergency)            COUNTY    NC
# 91962   Independent Diagnostic Testing Facility Pt A            COUNTY    MI
# 45791                              Podiatry Services            COUNTY    TX
# 916971                      Skilled Nursing Facility            COUNTY    GA
# 895189  Independent Diagnostic Testing Facility Pt B            COUNTY    NE
# 971433                    Preventive Health Services            COUNTY    WI
# 127111                         Ambulance (Emergency)            COUNTY    KS
# 956606  Independent Diagnostic Testing Facility Pt B            COUNTY    NJ
# 564430                Cardiac Rehabilitation Program            COUNTY    MI
# 701373                                   Home Health            COUNTY    KY
# 306565                                  Telemedicine            COUNTY    NC
# 508103   Clinical Laboratory (Billing Independently)            COUNTY    IN
# 753166   Clinical Laboratory (Billing Independently)             STATE    AZ
# 133076                Cardiac Rehabilitation Program            COUNTY    KY
# 686613                Cardiac Rehabilitation Program            COUNTY    AL
# 929428                     Ambulance (Non-Emergency)            COUNTY    GA
# 999831   Clinical Laboratory (Billing Independently)            COUNTY    MS
#
#                  county state_fips county_fips  \
# 865263          HANCOCK         19         081
# 454             CANDLER         13         043
# 113238         CROCKETT         48         105
# 679181          JACKSON         37         099
# 91962             BARRY         26         015
# 45791            KINNEY         48         271
# 916971           TAYLOR         13         269
# 895189        BOX BUTTE         31         013
# 971433            GREEN         55         045
# 127111         CRAWFORD         20         037
# 956606        HUNTERDON         34         019
# 564430          JACKSON         26         075
# 701373             TODD         21         219
# 306565       PERQUIMANS         37         143
# 508103           PUTNAM         18         133
# 753166          --ALL--         04
# 133076           SHELBY         21         211
# 686613           WALKER         01         127
# 929428           WALKER         13         295
# 999831  JEFFERSON DAVIS         28         065
#
#        number_of_fee_for_service_beneficiaries number_of_providers  \
# 865263                                   2,468                   4
# 454                                      1,367                   7
# 113238                                     513                   0
# 679181                                   6,068                   7
# 91962                                    6,281                  13
# 45791                                      563                   0
# 916971                                     877                   0
# 895189                                   2,520                   5
# 971433                                   6,517                  90
# 127111                                   6,104                   1
# 956606                                  21,404                  19
# 564430                                  21,103                   1
# 701373                                   1,770                   3
# 306565                                   2,738                   5
# 508103                                   4,908                  21
# 753166                                 836,792                 404
# 133076                                   5,545                   2
# 686613                                   7,496                   0
# 929428                                   9,284                   7
# 999831                                   1,711                  11
#
#        average_number_of_users_per_provider  ...  \
# 865263                                59.75  ...
# 454                                   34.29  ...
# 113238                                       ...
# 679181                                45.43  ...
# 91962                                214.54  ...
# 45791                                        ...
# 916971                                       ...
# 895189                                39.40  ...
# 971433                                40.96  ...
# 127111                               628.00  ...
# 956606                                78.84  ...
# 564430                                99.00  ...
# 701373                                42.00  ...
# 306565                                49.80  ...
# 508103                                91.24  ...
# 753166                             1,124.75  ...
# 133076                                21.50  ...
# 686613                                       ...
# 929428                                32.86  ...
# 999831                                86.27  ...
#
#        number_of_fee_for_service_beneficiaries_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166                                          0.10%
# 133076
# 686613
# 929428
# 999831
#
#        number_of_providers_change average_number_of_users_per_provider_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166                      1.51%                                    ( 2.53%)
# 133076
# 686613
# 929428
# 999831
#
#        percentage_of_users_out_of_ffs_beneficiaries_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166                                           ( 1.16%)
# 133076
# 686613
# 929428
# 999831
#
#        number_of_users_change average_number_of_providers_per_county_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166               ( 1.06%)                                      ( 0.65%)
# 133076
# 686613
# 929428
# 999831
#
#        number_of_dual_eligible_users_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166                             ( 9.94%)
# 133076
# 686613
# 929428
# 999831
#
#        percentage_of_dual_eligible_users_out_of_total_users_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166                                           ( 8.85%)
# 133076
# 686613
# 929428
# 999831
#
#        percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change  \
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166                                           ( 6.05%)
# 133076
# 686613
# 929428
# 999831
#
#        total_payment_change
# 865263
# 454
# 113238
# 679181
# 91962
# 45791
# 916971
# 895189
# 971433
# 127111
# 956606
# 564430
# 701373
# 306565
# 508103
# 753166             ( 8.50%)
# 133076
# 686613
# 929428
# 999831
#
# [20 rows x 48 columns]

# %%
# check last modified date
last_modified_header = response.headers.get('Last-Modified')
if last_modified_header:
    last_modified = datetime.strptime(last_modified_header, '%a, %d %b %Y %H:%M:%S GMT')
    print(f"Data was last modified: {last_modified}")

print(f"Total rows fetched: {len(df)}")
# Out:
# Data was last modified: 2024-07-08 14:03:45
# Total rows fetched: 1044711

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044711 entries, 0 to 1044710
# Data columns (total 48 columns):
#  #   Column                                                                                Non-Null Count    Dtype
# ---  ------                                                                                --------------    -----
#  0   reference_period                                                                      1044711 non-null  object
#  1   type_of_service                                                                       1044711 non-null  object
#  2   aggregation_level                                                                     1044711 non-null  object
#  3   state                                                                                 1044711 non-null  object
#  4   county                                                                                1044711 non-null  object
#  5   state_fips                                                                            1044711 non-null  object
#  6   county_fips                                                                           1044711 non-null  object
#  7   number_of_fee_for_service_beneficiaries                                               1044711 non-null  object
#  8   number_of_providers                                                                   1044711 non-null  object
#  9   average_number_of_users_per_provider                                                  1044711 non-null  object
#  10  percentage_of_users_out_of_ffs_beneficiaries                                          1044711 non-null  object
#  11  number_of_users                                                                       1044711 non-null  object
#  12  average_number_of_providers_per_county                                                1044711 non-null  object
#  13  number_of_dual_eligible_users                                                         1044711 non-null  object
#  14  percentage_of_dual_eligible_users_out_of_total_users                                  1044711 non-null  object
#  15  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries              1044711 non-null  object
#  16  total_payment                                                                         1044711 non-null  object
#  17  moratorium                                                                            1044711 non-null  object
#  18  number_of_fee_for_service_beneficiaries_dual_color                                    1044711 non-null  object
#  19  number_of_fee_for_service_beneficiaries_description                                   1044711 non-null  object
#  20  number_of_providers_dual_color                                                        1044711 non-null  object
#  21  number_of_providers_description                                                       1044711 non-null  object
#  22  average_number_of_users_per_provider_dual_color                                       1044711 non-null  object
#  23  average_number_of_users_per_provider_description                                      1044711 non-null  object
#  24  percentage_of_users_out_of_ffs_beneficiaries_dual_color                               1044711 non-null  object
#  25  percentage_of_users_out_of_ffs_beneficiaries_description                              1044711 non-null  object
#  26  number_of_users_dual_color                                                            1044711 non-null  object
#  27  number_of_users_description                                                           1044711 non-null  object
#  28  average_number_of_providers_per_county_dual_color                                     1044711 non-null  object
#  29  average_number_of_providers_per_county_description                                    1044711 non-null  object
#  30  number_of_dual_eligible_users_dual_color                                              1044711 non-null  object
#  31  number_of_dual_eligible_users_description                                             1044711 non-null  object
#  32  percentage_of_dual_eligible_users_out_of_total_users_dual_color                       1044711 non-null  object
#  33  percentage_of_dual_eligible_users_out_of_total_users_description                      1044711 non-null  object
#  34  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color   1044711 non-null  object
#  35  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description  1044711 non-null  object
#  36  total_payment_dual_color                                                              1044711 non-null  object
#  37  total_payment_description                                                             1044711 non-null  object
#  38  number_of_fee_for_service_beneficiaries_change                                        1044711 non-null  object
#  39  number_of_providers_change                                                            1044711 non-null  object
#  40  average_number_of_users_per_provider_change                                           1044711 non-null  object
#  41  percentage_of_users_out_of_ffs_beneficiaries_change                                   1044711 non-null  object
#  42  number_of_users_change                                                                1044711 non-null  object
#  43  average_number_of_providers_per_county_change                                         1044711 non-null  object
#  44  number_of_dual_eligible_users_change                                                  1044711 non-null  object
#  45  percentage_of_dual_eligible_users_out_of_total_users_change                           1044711 non-null  object
#  46  percentage_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change       1044711 non-null  object
#  47  total_payment_change                                                                  1044711 non-null  object
# dtypes: object(48)
# memory usage: 382.6+ MB

# %% [markdown]
# ## SQL Database Preperation
#
# ### Create seperate CSV file for SQL database

# %% [markdown]
# The data will be uploaded to a SQL database - `fwa_healthcare`
#
# Using a SQL database helps in efficiently managing and analyzing the data, ensuring that it remains consistent and readily accessible for reporting and decision-making. SQL databases are well-suited for handling large datasets, provide robust querying capabilities, and integrate seamlessly with Business Intelligence (BI) tools for advanced analysis and visualization.
#
# Here's how column names are adjusted in the DataFrame:
#
# 1. Read CSV Data:
# - Low Memory: Use low_memory=False to handle large datasets effectively.
# 2. Adjust Column Names:
# - Name Shortening: Shortens column names to adhere to SQL's 64-character limit.
# 3. Verify Column Lengths:
# - Validation: Check if any column names exceed 64 characters and adjust accordingly.
#
# #### Read CSV data

# %%
# read in data - might take a while because there 1m+ rows
df = pd.read_csv('data/cms_data.csv', low_memory=False) # we use 'low_memory=False' to isntruct Pandas to use more memorry and avoid mixed data types

# %% [markdown]
# #### Adjust Column Names

# %%
#adjust column names for sql db - sql can not have more than 64 characters per column names
df.columns = df.columns.str.replace('percentage', 'pct').str.replace('average', 'avg').str.replace('number', 'num')
df.columns
# Out:
# Index(['reference_period', 'type_of_service', 'aggregation_level', 'state',
#        'county', 'state_fips', 'county_fips',
#        'num_of_fee_for_service_beneficiaries', 'num_of_providers',
#        'avg_num_of_users_per_provider',
#        'pct_of_users_out_of_ffs_beneficiaries', 'num_of_users',
#        'avg_num_of_providers_per_county', 'num_of_dual_eligible_users',
#        'pct_of_dual_eligible_users_out_of_total_users',
#        'percent_dual_elig_ffs', 'total_payment', 'moratorium',
#        'num_of_fee_for_service_beneficiaries_dual_color',
#        'num_of_fee_for_service_beneficiaries_description',
#        'num_of_providers_dual_color', 'num_of_providers_description',
#        'avg_num_of_users_per_provider_dual_color',
#        'avg_num_of_users_per_provider_description',
#        'pct_of_users_out_of_ffs_beneficiaries_dual_color',
#        'pct_of_users_out_of_ffs_beneficiaries_description',
#        'num_of_users_dual_color', 'num_of_users_description',
#        'avg_num_of_providers_per_county_dual_color',
#        'avg_num_of_providers_per_county_description',
#        'num_of_dual_eligible_users_dual_color',
#        'num_of_dual_eligible_users_description',
#        'pct_of_dual_eligible_users_out_of_total_users_dual_color',
#        'pct_of_dual_eligible_users_out_of_total_users_description',
#        'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color',
#        'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description',
#        'total_payment_dual_color', 'total_payment_description',
#        'num_of_fee_for_service_beneficiaries_change',
#        'num_of_providers_change', 'avg_num_of_users_per_provider_change',
#        'pct_of_users_out_of_ffs_beneficiaries_change', 'num_of_users_change',
#        'avg_num_of_providers_per_county_change',
#        'num_of_dual_eligible_users_change',
#        'pct_of_dual_eligible_users_out_of_total_users_change',
#        'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change',
#        'total_payment_change'],
#       dtype='object')

# %%
# check if all column names are under 64 characters
for col in df.columns:
    if len(col) > 64:
        print(f"Column name '{col}' is too long: {len(col)} characters")
    else:
        print(f"Column name '{col}' is {len(col)} characters")

# check if any column name exceeds 64 characters
exceeds_64 = any(len(col) > 64 for col in df.columns)
if exceeds_64:
    print("Some column names exceed 64 characters.")
else:
    print("All column names are within 64 characters.")
# Out:
# Column name 'reference_period' is 16 characters
# Column name 'type_of_service' is 15 characters
# Column name 'aggregation_level' is 17 characters
# Column name 'state' is 5 characters
# Column name 'county' is 6 characters
# Column name 'state_fips' is 10 characters
# Column name 'county_fips' is 11 characters
# Column name 'num_of_fee_for_service_beneficiaries' is 36 characters
# Column name 'num_of_providers' is 16 characters
# Column name 'avg_num_of_users_per_provider' is 29 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries' is 37 characters
# Column name 'num_of_users' is 12 characters
# Column name 'avg_num_of_providers_per_county' is 31 characters
# Column name 'num_of_dual_eligible_users' is 26 characters
# Column name 'pct_of_dual_eligible_users_out_of_total_users' is 45 characters
# Column name 'percent_dual_elig_ffs' is 21 characters
# Column name 'total_payment' is 13 characters
# Column name 'moratorium' is 10 characters
# Column name 'num_of_fee_for_service_beneficiaries_dual_color' is 47 characters
# Column name 'num_of_fee_for_service_beneficiaries_description' is 48 characters
# Column name 'num_of_providers_dual_color' is 27 characters
# Column name 'num_of_providers_description' is 28 characters
# Column name 'avg_num_of_users_per_provider_dual_color' is 40 characters
# Column name 'avg_num_of_users_per_provider_description' is 41 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries_dual_color' is 48 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries_description' is 49 characters
# Column name 'num_of_users_dual_color' is 23 characters
# Column name 'num_of_users_description' is 24 characters
# Column name 'avg_num_of_providers_per_county_dual_color' is 42 characters
# Column name 'avg_num_of_providers_per_county_description' is 43 characters
# Column name 'num_of_dual_eligible_users_dual_color' is 37 characters
# Column name 'num_of_dual_eligible_users_description' is 38 characters
# Column name 'pct_of_dual_eligible_users_out_of_total_users_dual_color' is 56 characters
# Column name 'pct_of_dual_eligible_users_out_of_total_users_description' is 57 characters
# Column name 'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color' is too long: 76 characters
# Column name 'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description' is too long: 77 characters
# Column name 'total_payment_dual_color' is 24 characters
# Column name 'total_payment_description' is 25 characters
# Column name 'num_of_fee_for_service_beneficiaries_change' is 43 characters
# Column name 'num_of_providers_change' is 23 characters
# Column name 'avg_num_of_users_per_provider_change' is 36 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries_change' is 44 characters
# Column name 'num_of_users_change' is 19 characters
# Column name 'avg_num_of_providers_per_county_change' is 38 characters
# Column name 'num_of_dual_eligible_users_change' is 33 characters
# Column name 'pct_of_dual_eligible_users_out_of_total_users_change' is 52 characters
# Column name 'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change' is too long: 72 characters
# Column name 'total_payment_change' is 20 characters
# Some column names exceed 64 characters.

# %%
# adjust idnetified columns to be under 64 characters to meet sql requirement 
# create a dictionary to rename columns
rename_dict = {
    'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries': 'pct_dual_eligible_ffs_beneficiaries',
    'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color': 'pct_dual_eligible_ffs_beneficiaries_dual_color',
    'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description': 'pct_dual_eligible_ffs_beneficiaries_desc',
    'pct_of_dual_eligible_users_out_of_total_users_dual_color': 'pct_dual_eligible_total_users_dual_color',
    'pct_of_dual_eligible_users_out_of_total_users_description': 'pct_dual_eligible_total_users_desc',
    'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_dual_color': 'pct_dual_eligible_ffs_dual_color',
    'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_description': 'pct_dual_eligible_ffs_desc',
    'pct_of_dual_eligible_users_out_of_dual_eligible_ffs_beneficiaries_change': 'pct_dual_eligible_ffs_change',
}

# rename columns in the DataFrame
df.rename(columns=rename_dict, inplace=True)

# check the new column names and their lengths
for col in df.columns:
    print(f"Column name '{col}' is {len(col)} characters")
# Out:
# Column name 'reference_period' is 16 characters
# Column name 'type_of_service' is 15 characters
# Column name 'aggregation_level' is 17 characters
# Column name 'state' is 5 characters
# Column name 'county' is 6 characters
# Column name 'state_fips' is 10 characters
# Column name 'county_fips' is 11 characters
# Column name 'num_of_fee_for_service_beneficiaries' is 36 characters
# Column name 'num_of_providers' is 16 characters
# Column name 'avg_num_of_users_per_provider' is 29 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries' is 37 characters
# Column name 'num_of_users' is 12 characters
# Column name 'avg_num_of_providers_per_county' is 31 characters
# Column name 'num_of_dual_eligible_users' is 26 characters
# Column name 'pct_of_dual_eligible_users_out_of_total_users' is 45 characters
# Column name 'percent_dual_elig_ffs' is 21 characters
# Column name 'total_payment' is 13 characters
# Column name 'moratorium' is 10 characters
# Column name 'num_of_fee_for_service_beneficiaries_dual_color' is 47 characters
# Column name 'num_of_fee_for_service_beneficiaries_description' is 48 characters
# Column name 'num_of_providers_dual_color' is 27 characters
# Column name 'num_of_providers_description' is 28 characters
# Column name 'avg_num_of_users_per_provider_dual_color' is 40 characters
# Column name 'avg_num_of_users_per_provider_description' is 41 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries_dual_color' is 48 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries_description' is 49 characters
# Column name 'num_of_users_dual_color' is 23 characters
# Column name 'num_of_users_description' is 24 characters
# Column name 'avg_num_of_providers_per_county_dual_color' is 42 characters
# Column name 'avg_num_of_providers_per_county_description' is 43 characters
# Column name 'num_of_dual_eligible_users_dual_color' is 37 characters
# Column name 'num_of_dual_eligible_users_description' is 38 characters
# Column name 'pct_dual_eligible_total_users_dual_color' is 40 characters
# Column name 'pct_dual_eligible_total_users_desc' is 34 characters
# Column name 'pct_dual_eligible_ffs_dual_color' is 32 characters
# Column name 'pct_dual_eligible_ffs_desc' is 26 characters
# Column name 'total_payment_dual_color' is 24 characters
# Column name 'total_payment_description' is 25 characters
# Column name 'num_of_fee_for_service_beneficiaries_change' is 43 characters
# Column name 'num_of_providers_change' is 23 characters
# Column name 'avg_num_of_users_per_provider_change' is 36 characters
# Column name 'pct_of_users_out_of_ffs_beneficiaries_change' is 44 characters
# Column name 'num_of_users_change' is 19 characters
# Column name 'avg_num_of_providers_per_county_change' is 38 characters
# Column name 'num_of_dual_eligible_users_change' is 33 characters
# Column name 'pct_of_dual_eligible_users_out_of_total_users_change' is 52 characters
# Column name 'pct_dual_eligible_ffs_change' is 28 characters
# Column name 'total_payment_change' is 20 characters

# %% [markdown]
# #### Save DataFrame to CSV

# %%
output_dir = 'data'
output_file = os.path.join(output_dir, 'cms_data_sql.csv')

# create the directory if it does not exist
os.makedirs(output_dir, exist_ok=True)

# save DataFrame to CSV
df.to_csv(output_file, index=False)

print(f"DataFrame saved to {output_file}")
# Out:
# DataFrame saved to data/cms_data_sql.csv

# %% [markdown]
# ## References
#
# Bruce, P., & Bruce, A. (2017). *Practical statistics for data scientists: 50 essential concepts*. O'Reilly Media. https://www.amazon.com/Practical-Statistics-Data-Scientists-Essential/dp/1491952962
#
# Centers for Medicare & Medicaid Services. (2024). *Market saturation and utilization state-county data*. https://data.cms.gov/summary-statistics-on-use-and-payments/program-integrity-market-saturation-by-type-of-service/market-saturation-utilization-state-county
#
# Centers for Medicare and Medicaid Services. (2021). *Medicare fraud & abuse: Prevent, detect, report*. https://www.cms.gov/Outreach-and-Education/Medicare-Learning-Network-MLN/MLNProducts/Downloads/Fraud-Abuse-MLN4649244.pdf
#
# Federal Bureau of Investigation. (n.d.). *Health care fraud*. https://www.fbi.gov/investigate/white-collar-crime/health-care-fraud
#
# Kuhn, M., & Johnson, K. (2013). *Applied predictive modeling*. Springer. https://doi.org/10.1007/978-1-4614-6849-3
#
# MEDICARE-MEDICAID COORDINATION OFFICE & Centers for Medicare & Medicaid Services. (2023). *People dually eligible for Medicare and Medicaid*. In *Fact sheet – March 2023*. https://www.cms.gov/Medicare-Medicaid-Coordination/Medicare-and-Medicaid-Coordination/Medicare-Medicaid-Coordination-Office/Downloads/MMCO_Factsheet.pdf
